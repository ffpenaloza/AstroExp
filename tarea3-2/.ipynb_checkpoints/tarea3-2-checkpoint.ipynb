# %% [markdown]
# # Tarea 3, parte 2
# ---
#
# ## Problema 1
#
# De la base de datos preseleccionada, de la base de datos **I/337/tgas** bajo el alias **gaia**, la consulta selecciona las columnas:
#
# * gaia.source_id,
# * gaia.hip,
# * el resultado de: gaia.phot_g_mean_mag+5\*log10(gaia.parallax)-10 bajo el alias *g_mag_abs_gaia*,
# * el resultado de: gaia.phot_g_mean_mag+5\*log10(hip.plx)-10 bajo el alias *g_mag_abs_hip*,
# * hip."B-V"
#
# *gaia* y *hip* son tablas dentro de la base de datos.
#
# Con INNER JOIN se seleccionan también (en el mismo set de resultados) las columnas de la base **I/311/hip2** bajo el alias **hip**, para cada objeto seleccionado en la consulta anterior, es decir, donde gaia.hip coincida con hip.HIP.
#
# HIP es la id del objeto en el catálogo.
#
# Todo lo anterior se realiza solo para los objetos que cumplan a la vez las condiciones:
#
# * gaia.parallax/gaia.parallax_error >= 5 (_SNR del paralaje de gaia $\geq$5_)
# * hip.Plx/hip.e_Plx >= 5 (_SNR del paralaje de hip $\geq$5_)
# * hip."e_B-V" > 0.0
# * hip."e_B-V" <= 5
# * (2.5/log(10))\*(gaia.phot_g_mean_flux_error/gaia.phot_g_mean_flux) <= 0.05 (Error del flujo $\leq$ ~5%)
#
# Se procede a ejecutar la consulta mediante el código entregado para obtener un CMD

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from act4 import *

tap = "http://tapvizier.u-strasbg.fr/TAPVizieR/tap"
adql = """SELECT 
gaia.source_id, gaia.hip, gaia.phot_g_mean_mag+5*log10(gaia.parallax)-10 as g_mag_abs_gaia,
gaia.phot_g_mean_mag+5*log10(hip.plx)-10 as g_mag_abs_hip,
hip."B-V"
FROM "I/337/tgas" AS gaia
INNER JOIN "I/311/hip2" as hip
ON gaia.hip = hip.HIP
WHERE gaia.parallax/gaia.parallax_error >= 5 AND
hip.Plx/hip.e_Plx >= 5 AND
hip."e_B-V" > 0.0 and hip."e_B-V" <= 0.05 AND
(2.5/log(10))*(gaia.phot_g_mean_flux_error/gaia.phot_g_mean_flux) <= 0.05
"""

table = query_TAP(tap,adql)
print len(table)
# Out:
# WARNING: W35: /tmp/tmposrPTX:6:2: W35: 'value' attribute required for INFO elements [astropy.io.votable.exceptions]
# WARNING: W27: /tmp/tmposrPTX:18:2: W27: COOSYS deprecated in VOTable 1.2 [astropy.io.votable.exceptions]
# WARNING: W27: /tmp/tmposrPTX:20:2: W27: COOSYS deprecated in VOTable 1.2 [astropy.io.votable.exceptions]
# WARNING: W06: /tmp/tmposrPTX:35:3: W06: Invalid UCD 'phot.color': Unknown word 'phot.color' [astropy.io.votable.exceptions]
# 43564

# %%
plot_scatter_density(table,'B-V','g_mag_abs_hip','B-V','M','CMD Hipparcos')

# %% [markdown]
# ---
# ## Problema 2
#
#
# El **Sloan Digital Sky Survey** es el *survey* más grande que existe, con más del 35% del cielo mapeado. Observa en la banda óptica, infrarroja cercana y ultravioleta. Gracias a proyectos que se han instalado para trabajar junto al telescopio -como APOGEE, BOSS, etc- se han podido obtener resultados para temas desde estrellas y la Vía Láctea hasta quásares y cosmología.
#
# Para obtener datos del CAS del SDSS se hace un query mediante CASJobs.
# Se ocupa el context DR8, es decir, la base de datos que se consulta es la que contiene los resultados del Data Release 8.
#
# La consulta selecciona datos desde las tablas siguientes, con sus respectivos alias
#
# * SpecObj -> S
# * Galaxy -> G
# * GalSpecLine -> GSL
# * GalSpecIndx -> GSX
# * GalSpecExtra -> GSE
# * GalSpecInfo -> GSI
# * dbo.fGetnearestObjEQ(S.ra, S.dec, 0.06) -> N
#
# Notar que la última 'tabla' es en realidad el resultado de una operación. Se obtiene el objeto más cercano con una tolerancia de 0.06'.
# CROSS APPLY permite hacer un cruce de datos desde las distintas tablas. Es diferente de un JOIN puesto que ahora no se hace una unión de datos, sino que se ocupa la segunda tabla (o tercera, o cuarta... siendo SpecObj la primera) para definir valores. Los datos contenidos en las tablas de las subconsultas son inaccesibles desde el primer SELECT, por lo que se referencian.
#
# Se imponen las restricciones de que
#
# * Los ID de S coincidan con los de GSI, GSL, GSX, GSE
# * Las magnitudes en G estén entre 10 y 18, exclusive
# * El color u-r de G esté entre 0 y 6, exclusive
# * La magnitud u, g, r, i, z de S estén entre 10 y 25, exclusive
# * El error $\chi^2$ en S sea menor que 2
# * El error de z en S esté entre 0 y 0.01
# * Para los z en S que sean mayores a 0.02
#
# Solo entonces, se seleccionan las columnas especificadas en la consulta, que incluyen posiciones, nombres de instrumentos, redshift, velocidades, extinciones, magnitudes, flujos, y errores de medición de esos datos.
#
# El resultado se guardará en la base de datos personal que nos ofrece CASJobs, *mydb*, en la tabla *SDSS*.
#
# Después de 35 minutos la consulta termina de ejecutarse y se descarga el FITS con los resultados.
#
#
#
# Con estos datos se quiere construir un diagrama BPT. Como se explica en el trabajo de [Baldwin et al. 1982](http://adsabs.harvard.edu/abs/1981PASP...93....5B), esto es un diagrama que muestra líneas de emisión nebulares graficados más comunmente como [NII]6584/Ha versus [OIII]5007/Hb (BPT-NII), [SII]6717,6731/Ha versus [OIII]5007/Hb (BPT-SII) y [OI]6300/Ha versus [OIII]5007/Hb (BPT-OI). Permite distinguir el mecanismo de ionización del gas según la posición que ocupen los puntos en el diagrama.

# %%
import fitsio
import numpy as np

f = 'SDSS_ffpenaloza.fit'
h = fitsio.read_header(f, ext=1)
print h

data = fitsio.read(f)
idx = ((data['nii_6584_flux']>0) & (data['oiii_5007_flux']>0) & (data['h_alpha_flux']>0) & (data['h_beta_flux']>0))
nii = data['nii_6584_flux'][idx]/data['h_alpha_flux'][idx]
oiii = data['oiii_5007_flux'][idx]/data['h_beta_flux'][idx]

fig, ax = plt.subplots(figsize=(10,10))
ax.set_xlim(-1.5,0.5)
ax.set_ylim(-1.5,1.5)
ax.set_title('BPT NII diagram',fontsize=20)
ax.set_xlabel('log([NII]6584/Ha)',fontsize=16)
ax.set_ylabel('log([OIII]5007/Hb)',fontsize=16)

# Se muere si quiero hacerlo todo al mismo tiempo
mid = len(nii)/2
ax.plot(np.log10(nii[0:mid]), np.log10(oiii[0:mid]),'.k',alpha=.1)
ax.plot(np.log10(nii[mid+1:]), np.log10(oiii[mid+1:]),'.k',alpha=.1)

plt.show()
plt.close()
# Out:
# XTENSION= 'BINTABLE'
# BITPIX  =                    8
# NAXIS   =                    2
# NAXIS1  =                  182
# NAXIS2  =               661598
# PCOUNT  =                    0
# GCOUNT  =                    1
# TFIELDS =                   43
# TFORM1  = '1D'
# TTYPE1  = 'ra'
# TTYPE2  = 'dec'
# TFORM2  = '1D'
# TTYPE3  = 'mjd'
# TNULL3  =          -2147483648
# TFORM3  = '1J'
# TNULL4  =               -32768
# TFORM4  = '1I'
# TTYPE4  = 'plate'
# TTYPE5  = 'fiberID'
# TNULL5  =               -32768
# TFORM5  = '1I'
# TFORM6  = '1E'
# TTYPE6  = 'z'
# TTYPE7  = 'zErr'
# TFORM7  = '1E'
# TFORM8  = '1E'
# TTYPE8  = 'rChi2'
# TFORM9  = '1E'
# TTYPE9  = 'velDisp'
# TTYPE10 = 'velDispErr'
# TFORM10 = '1E'
# TFORM11 = '1E'
# TTYPE11 = 'extinction_r'
# TFORM12 = '1E'
# TTYPE12 = 'petroMag_r'
# TFORM13 = '1E'
# TTYPE13 = 'psfMag_r'
# TFORM14 = '1E'
# TTYPE14 = 'psfMagErr_r'
# TTYPE15 = 'modelMag_u'
# TFORM15 = '1E'
# TFORM16 = '1E'
# TTYPE16 = 'modelMagErr_u'
# ...

# %% [markdown]
# ---
# ## Problema 3
#
# Haciendo uso del módulo astroquery.sdss se bajan los SDSS spectral templates, que son modelos de espectros para distintos tipos de objetos. Se pudo haber hecho, con menos emoción, directamente de http://classic.sdss.org/dr5/algorithms/spectemplates/. Sin embargo, las imágenes del los templates disponibles en la web anterior se utilizarán como guía a la hora de marcar líneas de absorción/emisión.

# %%
from astroquery.sdss import SDSS

j = 1 # numero de plot
for tem in SDSS.AVAILABLE_TEMPLATES:
    result = SDSS.get_spectral_template(tem)
    
    for i in range(0, len(result)):
        hdulist = result[i]
        c0 = hdulist[0].header['coeff0']
        c1 = hdulist[0].header['coeff1']
        npix = hdulist[0].header['naxis1']
        wave = 10.**(c0 + c1 * np.arange(npix))
        flux = hdulist[0].data[0,:]    
        
        ######
        # por aqui irian las marcas de lineas
        # podria comprobar el tipo de objeto y marcar lineas correspondientes
        # cada set de lineas (por objeto) podria estar en un txt
        #####
        
        
        fig, ax = plt.subplots(figsize=(10,10))
        ax.set_title(repr(j)+'. '+repr(tem),fontsize=20)
        ax.set_xlabel('$\lambda$',fontsize=16)
        ax.set_ylabel('$F_\lambda$',fontsize=16)
        ax.plot(wave, flux, 'k-')
        plt.show()
        plt.close()
        
        j = j+1
